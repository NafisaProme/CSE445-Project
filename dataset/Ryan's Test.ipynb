# %%
import pandas as pd
df = pd.read_csv('startech.csv', usecols=['Price', 'Processor Brand'])
df.head(100)
# Out:
#                                   Price Processor Brand
# 29950                AVITA Essential 14           Intel
# 32999                        Freedom A9             AMD
# 32010  Dynabook Satellite Pro C40-G-109           Intel
# 33550  Dynabook Satellite Pro C40-G-13F           Intel
# 37950                   IdeaPad Slim 3i          Intel
# ...                                 ...             ...
# 75410               VivoBook 15 X1502ZA           Intel
# 73700                         IdeaPad 3             AMD
# 74327                         Liber V14           Intel
# 74327                         Liber V14           Intel
# 74327                         Liber V14           Intel
#
# [100 rows x 2 columns]
